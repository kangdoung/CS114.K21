# %% [markdown]
# <a href="https://colab.research.google.com/github/kangdoung/CS114.K21/blob/master/GK_R3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-701b1ce9-ebf5-41b5-9c07-47d12cdf424f" name="files[]" multiple disabled />
#      <output id="result-701b1ce9-ebf5-41b5-9c07-47d12cdf424f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data3_4f.csv to data3_4f.csv
# ...

# %% [markdown]
# Tải dữ liệu về máy và chỉnh sang định dạng csv

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# Thêm các thư viện cần thiết

# %%
df = pd.read_csv("data_pre222.csv", header = None)

# %% [markdown]
# Lựa chọn đặc trưng của model

# %%
x = df[0]
y = df[1]

# %%
x = np.array(x).reshape(-1,1)
y = np.array(y).reshape(-1,1)

# %%
Chia tập train và test theo tỉ lệ 8:2

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2,  random_state = 0)
x_train = np.array(x_train).reshape(-1,1)
y_train = np.array(y_train).reshape(-1,1)
x_test = np.array(x_test).reshape(-1,1)
y_test = np.array(x_test).reshape(-1,1)

# %%
from sklearn.metrics import mean_absolute_error

# %%
model = LinearRegression().fit(x_train, y_train)
pred = model.predict(x_test)
mean_absolute_error(pred, y_test)
# Out:
# 4991023.255343804

# %% [markdown]
# Độ hiệu quả của model

# %%
N = int(input())
print("thời gian dự đoán:")
data_temp = np.array(N)
data = np.array(data_temp).reshape(-1,1)
print(model.predict(N))

# %%
test_Data = pd.read_csv("data3.csv", header = None)
test_Data
# Out:
#               0        1
# 0      37837612  4.12166
# 1      37395246  3.92089
# 2      36610827  3.21540
# 3      29555651  2.54506
# 4      25928216  2.21831
# ...         ...      ...
# 10585  26872494  2.35117
# 10586  20753811  1.79155
# 10587  33520323  2.90918
# 10588  21243264  1.80292
# 10589  21380484  1.82795
#
# [10590 rows x 2 columns]

# %%
x_ts = test_Data[0]
y_ts = test_Data[1]

# %%
x_ts = np.array(x_ts).reshape(-1,1)
y_ts = np.array(y_ts).reshape(-1,1)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y, model.predict(x), squared= False)
# Out:
# 0.011974034723452417

# %% [markdown]
# MSE của model ban đầu

# %%
val = model.predict(x_ts)
mean_squared_error(y_ts, val, squared= False)
# Out:
# 0.143676151604917

# %% [markdown]
# Do MSE của tập dữ liệu mới là 0.14 lớn hơn so với MSE của tập dữ liệu ban đầu là 0.011 nên kết quả là tệ hơn

# %% [markdown]
# Có thê do model chưa bao quát hết được các trường hợp xảy ra -> cần thêm 1 hoặc vài feature để tăng tính phức tạp của model

# %%
model.score(x_ts, y_ts)
# Out:
# 0.9284898234057857

# %% [markdown]
# #Thêm feature

# %% [markdown]
# Thêm feature bằng cách mở rộng thêm chiều dữ liệu trong dữ liệu ban đầu . Các feature mưới thêm vào là N, logN, NlogN

# %%
df1 = pd.read_csv("data3_4f.csv", header = None)

# %%
df1
# Out:
#               0            1          2        3
# 0      37837612  952498228.1  25.173318  4.12166
# 1      37395246  940727954.2  25.156352  3.92089
# 2      36610827  919875109.9  25.125767  3.21540
# 3      29555651  733480541.5  24.816931  2.54506
# 4      25928216  638560612.1  24.628020  2.21831
# ...         ...          ...        ...      ...
# 10585  26872494  663203125.4  24.679627  2.35117
# 10586  20753811  504460247.1  24.306873  1.79155
# 10587  33520323  837958891.1  24.998533  2.90918
# 10588  21243264  517071712.3  24.340502  1.80292
# 10589  21380484  520610320.7  24.349791  1.82795
#
# [10590 rows x 4 columns]

# %%
df1.columns
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
feature = [0, 1, 2]
x_3 = df1[feature]
x_3.describe()
# Out:
#                   0             1             2
# count  1.059000e+04  1.059000e+04  10590.000000
# mean   2.999277e+07  7.457706e+08     24.810591
# std    5.759381e+06  1.512707e+08      0.284533
# min    2.000026e+07  4.850767e+08     24.253516
# 25%    2.503806e+07  6.153759e+08     24.577619
# 50%    2.994436e+07  7.436916e+08     24.835781
# 75%    3.500845e+07  8.773538e+08     25.061200
# max    3.999734e+07  1.010069e+09     25.253401

# %%
y_3 = df1[3]

# %%
train_X, test_X, train_Y, test_Y = train_test_split(x_3, y_3, test_size = 0.2, random_state = 0)

# %%
model_3f = LinearRegression().fit(train_X,train_Y)

# %%
mean_absolute_error(model_3f.predict(test_X), test_Y)
# Out:
# 0.042801719120072045

# %% [markdown]
# Model mới có MAE tốt hơn so với model cũ nhưng không lớn hơn nhiều
